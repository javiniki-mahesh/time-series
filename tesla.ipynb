# %%
# !pip install pandas-datareader

# %%
# !pip install yfinance

# %%
import pandas_datareader as pdr

# %%
import yfinance

# %%
from datetime import datetime

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import rcParams
rcParams['figure.figsize'] = (16,8)

# %%
tesla = yfinance.download(tickers = 'tsla')
tesla
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...                ...         ...         ...         ...         ...
# 2023-04-10  179.940002  185.100006  176.110001  184.509995  184.509995
# 2023-04-11  186.690002  189.190002  185.649994  186.789993  186.789993
# 2023-04-12  190.740005  191.580002  180.309998  180.539993  180.539993
# 2023-04-13  182.960007  186.500000  180.940002  185.899994  185.899994
# 2023-04-14  183.949997  186.279999  182.009995  185.000000  185.000000
#
#                Volume
# Date
# ...

# %%
tesla.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-04-10  179.940002  185.100006  176.110001  184.509995  184.509995
# 2023-04-11  186.690002  189.190002  185.649994  186.789993  186.789993
# 2023-04-12  190.740005  191.580002  180.309998  180.539993  180.539993
# 2023-04-13  182.960007  186.500000  180.940002  185.899994  185.899994
# 2023-04-14  183.949997  186.279999  182.009995  185.000000  185.000000
#
#                Volume
# Date
# 2023-04-10  142154600
# 2023-04-11  115770900
# 2023-04-12  150256300
# 2023-04-13  112933000
# 2023-04-14   96306500

# %%
tesla['High'].max()
# Out:
# 414.4966735839844

# %%
# to find which date we have got max price
tesla['High'][tesla['High'] == tesla['High'].max()]
# Out:
# Date
# 2021-11-04    414.496674
# Name: High, dtype: float64

# %%
tesla['High'].min()
# Out:
# 1.108667016029358

# %%
# to find which date we have got max price
tesla['High'][tesla['High'] == tesla['High'].min()]
# Out:
# Date
# 2010-07-07    1.108667
# Name: High, dtype: float64

# %%
tesla['High'].mean()
# Out:
# 62.81456870401324

# %%
tesla['High'].median()
# Out:
# 16.67133331298828

# %%
# highest volume 
tesla['Volume'].max()
# Out:
# 914082000

# %%
# least volume
tesla['Volume'].min()
# Out:
# 1777500

# %%
tesla.isna().sum() > 0
# Out:
# Open         False
# High         False
# Low          False
# Close        False
# Adj Close    False
# Volume       False
# dtype: bool

# %%
tesla[tesla[['Open', 'Close']].duplicated() == True]
# In these days the market opened at same price and closed at same price
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2013-01-08   2.300000   2.300000   2.207333   2.245333   2.245333  19260000
# 2017-11-10  20.166668  20.557333  20.123333  20.199333  20.199333  69381000

# %%
tesla[tesla[['High', 'Low']].duplicated() == True]
# combination of high and low repeated previously
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2012-10-02   1.952000   1.992667   1.933333   1.986667   1.986667  10935000
# 2012-10-11   1.929333   1.932000   1.883333   1.888000   1.888000   6759000
# 2012-11-13   2.086000   2.133333   2.048000   2.107333   2.107333  14974500
# 2018-03-13  21.907333  23.147333  21.766666  22.789333  22.789333  89487000

# %%
tesla[tesla['Volume'].duplicated() == True]
# In all these days repeated the Volume of sold
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2011-10-20    1.829333    1.831333    1.800000    1.822667    1.822667
# 2011-11-09    2.058000    2.099333    2.020000    2.058667    2.058667
# 2011-12-05    2.235333    2.333333    2.228667    2.294667    2.294667
# 2012-01-06    1.813333    1.852667    1.760667    1.794000    1.794000
# 2012-01-31    1.993333    2.000000    1.924667    1.938000    1.938000
# 2012-03-16    2.326667    2.392667    2.322000    2.354667    2.354667
# 2012-04-12    2.251333    2.298667    2.194667    2.229333    2.229333
# 2012-04-24    2.121333    2.146667    2.066667    2.121333    2.121333
# 2012-10-02    1.952000    1.992667    1.933333    1.986667    1.986667
# 2012-10-12    1.888000    1.915333    1.833333    1.842667    1.842667
# 2012-12-05    2.254667    2.279333    2.238667    2.247333    2.247333
# 2013-01-10    2.258000    2.266000    2.225333    2.235333    2.235333
# ...

# %%
tesla['High'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# looks like a rapid change from 2020
# using xlim from 2020 till today
tesla['High'].plot(xlim = ['2020 - 01 -01',datetime.now().date()])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
tesla.index
# Out:
# DatetimeIndex(['2010-06-29', '2010-06-30', '2010-07-01', '2010-07-02',
#                '2010-07-06', '2010-07-07', '2010-07-08', '2010-07-09',
#                '2010-07-12', '2010-07-13',
#                ...
#                '2023-03-31', '2023-04-03', '2023-04-04', '2023-04-05',
#                '2023-04-06', '2023-04-10', '2023-04-11', '2023-04-12',
#                '2023-04-13', '2023-04-14'],
#               dtype='datetime64[ns]', name='Date', length=3221, freq=None)

# %%
tesla.loc['2023-04-11']
# Out:
# Open         1.866900e+02
# High         1.891900e+02
# Low          1.856500e+02
# Close        1.867900e+02
# Adj Close    1.867900e+02
# Volume       1.157709e+08
# Name: 2023-04-11 00:00:00, dtype: float64

# %%
# till now date is acting as index
# if we want to reset index

# %%
tesla = tesla.reset_index()

# %%
tesla
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1    2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2    2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3    2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4    2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...         ...         ...         ...         ...         ...         ...
# 3216 2023-04-10  179.940002  185.100006  176.110001  184.509995  184.509995
# 3217 2023-04-11  186.690002  189.190002  185.649994  186.789993  186.789993
# 3218 2023-04-12  190.740005  191.580002  180.309998  180.539993  180.539993
# 3219 2023-04-13  182.960007  186.500000  180.940002  185.899994  185.899994
# 3220 2023-04-14  183.949997  186.279999  182.009995  185.000000  185.000000
#
#          Volume
# 0     281494500
# 1     257806500
# ...

# %%
tesla.index
# Out:
# RangeIndex(start=0, stop=3221, step=1)

# %%
# whenever we want to set a column as index we could follow this
tesla = tesla.set_index('High')
tesla.head()
# Out:
#                Date      Open       Low     Close  Adj Close     Volume
# High
# 1.666667 2010-06-29  1.266667  1.169333  1.592667   1.592667  281494500
# 2.028000 2010-06-30  1.719333  1.553333  1.588667   1.588667  257806500
# 1.728000 2010-07-01  1.666667  1.351333  1.464000   1.464000  123282000
# 1.540000 2010-07-02  1.533333  1.247333  1.280000   1.280000   77097000
# 1.333333 2010-07-06  1.333333  1.055333  1.074000   1.074000  103003500

# %%
tesla.index
# Out:
# Float64Index([1.6666669845581055, 2.0280001163482666, 1.7280000448226929,
#               1.5399999618530273, 1.3333330154418945,  1.108667016029358,
#               1.1679999828338623, 1.1933330297470093, 1.2046669721603394,
#               1.2426669597625732,
#               ...
#                207.7899932861328, 202.69000244140625, 198.74000549316406,
#               190.67999267578125, 186.38999938964844, 185.10000610351562,
#               189.19000244140625,  191.5800018310547,              186.5,
#               186.27999877929688],
#              dtype='float64', name='High', length=3221)

# %%
tesla = tesla.set_index('Date')
tesla.head()
# Out:
#                 Open       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.055333  1.074000   1.074000  103003500

# %% [markdown]
# ###### today and now both gives same result

# %%
datetime.today()
# Out:
# datetime.datetime(2023, 4, 15, 12, 49, 10, 374930)

# %%
datetime.now()
# Out:
# datetime.datetime(2023, 4, 15, 12, 49, 18, 706644)

# %%
# different functions

# %%
datetime.now().day
# Out:
# 15

# %%
datetime.now().month
# Out:
# 4

# %%
datetime.now().year
# Out:
# 2023

# %%
# Monday is 0,
# Tuesday is 1,
# Wednesday is 2 etc
datetime.now().weekday()
# Out:
# 5

# %%
datetime.now().hour
# Out:
# 12

# %%
datetime.now().minute
# Out:
# 49

# %%
datetime.now().second
# Out:
# 22

# %%
datetime.now().microsecond
# Out:
# 912688

# %%
plt.plot()

# %%
plt.plot(tesla.loc['2020-01-01':'2021-09-01'].index, tesla.loc['2020-01-01':'2021-09-01']['Open'])

# %%
# another way

index=tesla.loc['2020-01-01':'2021-09-01'].index
share_open=tesla.loc['2020-01-01':'2021-09-01']['Open']

figure,axis=plt.subplots()
plt.tight_layout()
## Preventing overlapping
figure.autofmt_xdate()
axis.plot(index,share_open)

# %% [markdown]
# ### Time resampling

# %% [markdown]
# Reference : https://towardsdatascience.com/resample-function-of-pandas-79b17ec82a78#:~:text=Resampling%20is%20used%20in%20time,DatetimeIndex%2C%20PeriodIndex%2C%20or%20TimedeltaIndex.

# %% [markdown]
# ![1_JKRKrjcDUMUIOTE6VOTwGQ.webp](attachment:1_JKRKrjcDUMUIOTE6VOTwGQ.webp)

# %% [markdown]
# queries : https://chat.openai.com/c/918c0849-7cd2-4042-b899-e8d7ec30fad3

# %% [markdown]
# There are several time resampling techniques available in pandas:
#
#     Downsampling: Downsampling refers to the process of aggregating data from a higher frequency to a lower frequency. This is done by grouping data over a longer time interval, such as from hourly to daily data.
#
#     Upsampling: Upsampling is the opposite of downsampling, and refers to the process of increasing the frequency of a time series. This is done by introducing additional data points in the time series, typically by using interpolation techniques.
#
#     Rolling window: A rolling window is a technique for calculating statistics on a time series by sliding a window of fixed size over the data. This is useful for smoothing the data and identifying trends.
#
#     Expanding window: An expanding window is a technique that calculates statistics over an increasingly larger portion of the time series. This can be useful for identifying long-term trends in the data.
#
#     Resampling with custom frequencies: Pandas also allows you to resample time series data using custom frequencies, such as every 2 weeks or every 6 months. This can be useful if you need to analyze data at a specific frequency that is not available by default.
#
#     Overall, the choice of resampling technique depends on the specific problem you are trying to solve and the characteristics of your time series data.

# %%
tesla.tail()
# Out:
#                   Open         Low       Close   Adj Close     Volume
# Date
# 2023-04-10  179.940002  176.110001  184.509995  184.509995  142154600
# 2023-04-11  186.690002  185.649994  186.789993  186.789993  115770900
# 2023-04-12  190.740005  180.309998  180.539993  180.539993  150256300
# 2023-04-13  182.960007  180.940002  185.899994  185.899994  112933000
# 2023-04-14  183.949997  182.009995  185.000000  185.000000   96306500

# %% [markdown]
# ### Downsampling

# %%
# min annual frequency
tesla.resample(rule = 'A').min()
# Out:
#                   Open         Low       Close   Adj Close    Volume
# Date
# 2010-12-31    1.076000    0.998667    1.053333    1.053333   1777500
# 2011-12-31    1.452000    1.407333    1.455333    1.455333   3594000
# 2012-12-31    1.774667    1.509333    1.519333    1.519333   5473500
# 2013-12-31    2.205333    2.140667    2.194000    2.194000   6603000
# 2014-12-31    9.366667    9.111333    9.289333    9.289333  19983000
# 2015-12-31   12.388667   12.093333   12.333333   12.333333  10620000
# 2016-12-31    9.488000    9.403333    9.578000    9.578000  24892500
# 2017-12-31   14.316667   14.064000   14.466000   14.466000  32800500
# 2018-12-31   16.851999   16.306000   16.704000   16.704000  46210500
# 2019-12-31   12.073333   11.799333   11.931333   11.931333  36984000
# 2020-12-31   24.980000   23.367332   24.081333   24.081333  52073100
# 2021-12-31  184.183334  179.830002  187.666672  187.666672  29401800
# ...

# %%
# max annual frequency
tesla.resample(rule = 'A').max()
# Out:
#                   Open         Low       Close   Adj Close     Volume
# Date
# 2010-12-31    2.391333    2.316667    2.364667    2.364667  281494500
# 2011-12-31    2.308667    2.268667    2.329333    2.329333  172767000
# 2012-12-31    2.546000    2.474000    2.534000    2.534000   85206000
# 2013-12-31   12.930667   12.558000   12.891333   12.891333  557458500
# 2014-12-31   19.177999   18.693333   19.069332   19.069332  490225500
# 2015-12-31   18.680000   18.420000   18.817333   18.817333  234744000
# 2016-12-31   17.763332   16.967333   17.694668   17.694668  356136000
# 2017-12-31   25.779333   25.290001   25.666668   25.666668  296871000
# 2018-12-31   25.000000   24.474667   25.304667   25.304667  504745500
# 2019-12-31   29.000000   28.423332   28.729334   28.729334  450091500
# 2020-12-31  233.330002  230.373337  235.223328  235.223328  914082000
# 2021-12-31  411.470001  405.666656  409.970001  409.970001  268189500
# ...

# %% [markdown]
# The rule parameter in the resample() method of pandas specifies the frequency at which the data will be resampled. It can take different values depending on the desired frequency of the resampled data. Some of the most commonly used frequency values for the rule parameter are:
#
#     'D' or 'day': resample to daily frequency.
#     'W' or 'week': resample to weekly frequency.
#     'M' or 'month': resample to end-of-month frequency.
#     'Q' or 'quarter': resample to quarterly frequency.
#     'Y' or 'year': resample to annual frequency.
#
# In addition to these, pandas also allows custom date offsets to be specified using the DateOffset class, such as '2W' for every 2 weeks or '6M' for every 6 months.
#
# The rule parameter can also take a combination of these frequency values and date offsets, such as '2D' for every 2 days or '3M1W' for every 3 months and 1 week.
#
# Overall, the choice of rule depends on the specific problem you are trying to solve and the characteristics of your time series data.

# %%
tesla.resample(rule='y').min()
# Out:
#                   Open         Low       Close   Adj Close    Volume
# Date
# 2010-12-31    1.076000    0.998667    1.053333    1.053333   1777500
# 2011-12-31    1.452000    1.407333    1.455333    1.455333   3594000
# 2012-12-31    1.774667    1.509333    1.519333    1.519333   5473500
# 2013-12-31    2.205333    2.140667    2.194000    2.194000   6603000
# 2014-12-31    9.366667    9.111333    9.289333    9.289333  19983000
# 2015-12-31   12.388667   12.093333   12.333333   12.333333  10620000
# 2016-12-31    9.488000    9.403333    9.578000    9.578000  24892500
# 2017-12-31   14.316667   14.064000   14.466000   14.466000  32800500
# 2018-12-31   16.851999   16.306000   16.704000   16.704000  46210500
# 2019-12-31   12.073333   11.799333   11.931333   11.931333  36984000
# 2020-12-31   24.980000   23.367332   24.081333   24.081333  52073100
# 2021-12-31  184.183334  179.830002  187.666672  187.666672  29401800
# ...

# %%
tesla.resample(rule = 'y').max()
# Out:
#                   Open         Low       Close   Adj Close     Volume
# Date
# 2010-12-31    2.391333    2.316667    2.364667    2.364667  281494500
# 2011-12-31    2.308667    2.268667    2.329333    2.329333  172767000
# 2012-12-31    2.546000    2.474000    2.534000    2.534000   85206000
# 2013-12-31   12.930667   12.558000   12.891333   12.891333  557458500
# 2014-12-31   19.177999   18.693333   19.069332   19.069332  490225500
# 2015-12-31   18.680000   18.420000   18.817333   18.817333  234744000
# 2016-12-31   17.763332   16.967333   17.694668   17.694668  356136000
# 2017-12-31   25.779333   25.290001   25.666668   25.666668  296871000
# 2018-12-31   25.000000   24.474667   25.304667   25.304667  504745500
# 2019-12-31   29.000000   28.423332   28.729334   28.729334  450091500
# 2020-12-31  233.330002  230.373337  235.223328  235.223328  914082000
# 2021-12-31  411.470001  405.666656  409.970001  409.970001  268189500
# ...

# %%
tesla.loc['23-4-14']
# Out:
# Open         1.442200e+01
# Low          1.380000e+01
# Close        1.386600e+01
# Adj Close    1.386600e+01
# Volume       1.094340e+08
# Name: 2014-04-23 00:00:00, dtype: float64

# %% [markdown]
# One important key point in datetime is we could get the result even the format is not exactly same
#
#     if the format is change we get warning
#     some considerations in presenting
#     ex : 2021 whole year
#         2021-1-1 even 0's not availabe it works
#         21-1-31 short form also works

# %%
month_tesla = tesla.loc['2021-1-30' : '2022']
month_tesla
# Out:
#                   Open         Low       Close   Adj Close     Volume
# Date
# 2021-02-01  271.429993  265.186676  279.936676  279.936676   76174200
# 2021-02-02  281.559998  280.733337  290.929993  290.929993   73038600
# 2021-02-03  292.339996  284.353333  284.896667  284.896667   55030500
# 2021-02-04  285.000000  277.806671  283.329987  283.329987   47438100
# 2021-02-05  281.666656  279.656677  284.076660  284.076660   55699800
# ...                ...         ...         ...         ...        ...
# 2022-12-23  126.370003  121.019997  123.150002  123.150002  166989700
# 2022-12-27  117.500000  108.760002  109.099998  109.099998  208643400
# 2022-12-28  110.349998  108.239998  112.709999  112.709999  221070500
# 2022-12-29  120.389999  117.500000  121.820000  121.820000  221923300
# 2022-12-30  119.949997  119.750000  123.180000  123.180000  157777300
#
# [484 rows x 5 columns]

# %%
month_tesla.resample(rule = 'M').min()
# Out:
#                   Open         Low       Close   Adj Close    Volume
# Date
# 2021-02-28  220.710007  206.333328  225.166672  225.166672  45473100
# 2021-03-31  200.183334  179.830002  187.666672  187.666672  71196600
# 2021-04-30  222.529999  219.806671  220.583328  220.583328  64311300
# 2021-05-31  184.183334  182.326660  187.820007  187.820007  65705700
# 2021-06-30  193.236664  190.406662  190.946671  190.946671  48615900
# 2021-07-31  209.456665  206.820007  214.460007  214.460007  41859900
# 2021-08-31  223.250000  216.279999  221.903336  221.903336  29401800
# 2021-09-30  244.083328  236.283340  243.389999  243.389999  35842500
# 2021-10-31  258.733337  254.529999  258.406677  258.406677  36741600
# 2021-11-30  334.436676  326.200012  337.796661  337.796661  35042700
# 2021-12-31  303.566681  295.373322  299.980011  299.980011  40733700
# 2022-01-31  277.186676  264.003326  276.366669  276.366669  66063300
# ...

# %%
weekly_tesla = month_tesla.loc['2022-09-30': '2022-12-31']
weekly_tesla.shape
# Out:
# (64, 5)

# %%
weekly_tesla.resample(rule = 'W').max()
# For every sunday it is repeating
# Out:
#                   Open         Low       Close   Adj Close     Volume
# Date
# 2022-10-02  266.149994  262.470001  265.250000  265.250000   67726600
# 2022-10-09  254.500000  242.009995  249.440002  249.440002  109578500
# 2022-10-16  224.009995  218.360001  222.960007  222.960007   94124500
# 2022-10-23  229.500000  217.779999  222.039993  222.039993  117798100
# 2022-10-30  229.770004  222.850006  228.520004  228.520004  100446800
# 2022-11-06  234.050003  227.279999  227.820007  227.820007   98622200
# 2022-11-13  208.649994  196.660004  197.080002  197.080002  132703000
# 2022-11-20  195.880005  192.059998  194.419998  194.419998   92226600
# 2022-11-27  185.059998  180.630005  183.199997  183.199997  109536700
# 2022-12-04  197.080002  191.800003  194.860001  194.860001  109186400
# 2022-12-11  189.440002  180.550003  182.449997  182.449997  104872300
# 2022-12-18  176.100006  167.520004  167.820007  167.820007  175862700
# ...

# %%
daily_tesla = weekly_tesla.loc['2022-11-06' : '2022-11-27']
daily_tesla.shape
# Out:
# (14, 5)

# %%
# this data is typicall in days, but we will apply D
daily_tesla
# Out:
#                   Open         Low       Close   Adj Close     Volume
# Date
# 2022-11-07  208.649994  196.660004  197.080002  197.080002   93916500
# 2022-11-08  194.020004  186.750000  191.300003  191.300003  128803400
# 2022-11-09  190.779999  177.119995  177.589996  177.589996  127062700
# 2022-11-10  189.899994  180.029999  190.720001  190.720001  132703000
# 2022-11-11  186.000000  182.589996  195.970001  195.970001  114403600
# 2022-11-14  192.770004  186.339996  190.949997  190.949997   92226600
# 2022-11-15  195.880005  192.059998  194.419998  194.419998   91293800
# 2022-11-16  191.509995  185.660004  186.919998  186.919998   66567600
# 2022-11-17  183.960007  180.899994  183.169998  183.169998   64336000
# 2022-11-18  185.050003  176.550003  180.190002  180.190002   76048900
# 2022-11-21  175.850006  167.539993  167.869995  167.869995   92882700
# 2022-11-22  168.630005  166.190002  169.910004  169.910004   78452300
# ...

# %%
daily_tesla.resample(rule = 'D').max()
# But the interesting part is we could get the values that are not part of dataset
# Out:
#                   Open         Low       Close   Adj Close       Volume
# Date
# 2022-11-07  208.649994  196.660004  197.080002  197.080002   93916500.0
# 2022-11-08  194.020004  186.750000  191.300003  191.300003  128803400.0
# 2022-11-09  190.779999  177.119995  177.589996  177.589996  127062700.0
# 2022-11-10  189.899994  180.029999  190.720001  190.720001  132703000.0
# 2022-11-11  186.000000  182.589996  195.970001  195.970001  114403600.0
# 2022-11-12         NaN         NaN         NaN         NaN          NaN
# 2022-11-13         NaN         NaN         NaN         NaN          NaN
# 2022-11-14  192.770004  186.339996  190.949997  190.949997   92226600.0
# 2022-11-15  195.880005  192.059998  194.419998  194.419998   91293800.0
# 2022-11-16  191.509995  185.660004  186.919998  186.919998   66567600.0
# 2022-11-17  183.960007  180.899994  183.169998  183.169998   64336000.0
# 2022-11-18  185.050003  176.550003  180.190002  180.190002   76048900.0
# ...

# %%
month_tesla.resample(rule = 'Q').max()
# end of quarter
# Out:
#                   Open         Low       Close   Adj Close     Volume
# Date
# 2021-03-31  292.339996  284.916656  290.929993  290.929993  268189500
# 2021-06-30  256.899994  244.203339  254.106674  254.106674  147052200
# 2021-09-30  262.399994  258.333344  263.786682  263.786682  100847400
# 2021-12-31  411.470001  405.666656  409.970001  409.970001  188556300
# 2022-03-31  396.516663  378.679993  399.926666  399.926666  151565700
# 2022-06-30  378.766663  362.433319  381.816681  381.816681  144973200
# 2022-09-30  311.666656  305.579987  309.320007  309.320007  142032300
# 2022-12-31  254.500000  242.009995  249.440002  249.440002  221923300

# %%
month_tesla.resample(rule='BQS').max()
# start of quarter
# Out:
#                   Open         Low       Close   Adj Close     Volume
# Date
# 2021-01-01  292.339996  284.916656  290.929993  290.929993  268189500
# 2021-04-01  256.899994  244.203339  254.106674  254.106674  147052200
# 2021-07-01  262.399994  258.333344  263.786682  263.786682  100847400
# 2021-10-01  411.470001  405.666656  409.970001  409.970001  188556300
# 2022-01-03  396.516663  378.679993  399.926666  399.926666  151565700
# 2022-04-01  378.766663  362.433319  381.816681  381.816681  144973200
# 2022-07-01  311.666656  305.579987  309.320007  309.320007  142032300
# 2022-10-03  254.500000  242.009995  249.440002  249.440002  221923300

# %%
tesla.resample(rule = 'Y').max()['Open']
# Out:
# Date
# 2010-12-31      2.391333
# 2011-12-31      2.308667
# 2012-12-31      2.546000
# 2013-12-31     12.930667
# 2014-12-31     19.177999
# 2015-12-31     18.680000
# 2016-12-31     17.763332
# 2017-12-31     25.779333
# 2018-12-31     25.000000
# 2019-12-31     29.000000
# 2020-12-31    233.330002
# 2021-12-31    411.470001
# 2022-12-31    396.516663
# 2023-12-31    211.759995
# Freq: A-DEC, Name: Open, dtype: float64

# %%
tesla.resample(rule = 'Y').max()['Open'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
tesla.resample(rule = 'Y').max()['Volume'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
tesla.resample(rule = 'Y').max()['Open'].plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
weekly_tesla['Open'].plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Upsampling

# %%
time_tesla = tesla['2023-04-12' : '2023-04-14']
time_tesla
# Out:
#                   Open         Low       Close   Adj Close     Volume
# Date
# 2023-04-12  190.740005  180.309998  180.539993  180.539993  150256300
# 2023-04-13  182.960007  180.940002  185.899994  185.899994  112933000
# 2023-04-14  183.949997  182.009995  185.000000  185.000000   96306500

# %%
time_tesla.resample(rule = "H").max()
# when we are trying to do upsampling we will get lot of NaN values
# If we really want to go with upsampling we could handle NaN values
# Out:
#                            Open         Low       Close   Adj Close  \
# Date
# 2023-04-12 00:00:00  190.740005  180.309998  180.539993  180.539993
# 2023-04-12 01:00:00         NaN         NaN         NaN         NaN
# 2023-04-12 02:00:00         NaN         NaN         NaN         NaN
# 2023-04-12 03:00:00         NaN         NaN         NaN         NaN
# 2023-04-12 04:00:00         NaN         NaN         NaN         NaN
# 2023-04-12 05:00:00         NaN         NaN         NaN         NaN
# 2023-04-12 06:00:00         NaN         NaN         NaN         NaN
# 2023-04-12 07:00:00         NaN         NaN         NaN         NaN
# 2023-04-12 08:00:00         NaN         NaN         NaN         NaN
# 2023-04-12 09:00:00         NaN         NaN         NaN         NaN
# 2023-04-12 10:00:00         NaN         NaN         NaN         NaN
# 2023-04-12 11:00:00         NaN         NaN         NaN         NaN
# 2023-04-12 12:00:00         NaN         NaN         NaN         NaN
# ...

# %% [markdown]
# ### Rolling

# %%
weekly_tesla['Open'].rolling(5).max()
# Out:
# Date
# 2022-09-30           NaN
# 2022-10-03           NaN
# 2022-10-04           NaN
# 2022-10-05           NaN
# 2022-10-06    266.149994
#                  ...
# 2022-12-23    154.000000
# 2022-12-27    146.050003
# 2022-12-28    139.339996
# 2022-12-29    136.000000
# 2022-12-30    126.370003
# Name: Open, Length: 64, dtype: float64

# %%
month_tesla['Open:30 days rolling']=month_tesla['Open'].rolling(8).mean()
# Out:
# C:\Users\mahes\AppData\Local\Temp\ipykernel_6280\3188922027.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_tesla['Open:30 days rolling']=month_tesla['Open'].rolling(8).mean()

# %%
month_tesla.head(10)
# Out:
#                   Open         Low       Close   Adj Close     Volume  \
# Date
# 2021-02-01  271.429993  265.186676  279.936676  279.936676   76174200
# 2021-02-02  281.559998  280.733337  290.929993  290.929993   73038600
# 2021-02-03  292.339996  284.353333  284.896667  284.896667   55030500
# 2021-02-04  285.000000  277.806671  283.329987  283.329987   47438100
# 2021-02-05  281.666656  279.656677  284.076660  284.076660   55699800
# 2021-02-08  289.890015  284.916656  287.806671  287.806671   60485100
# 2021-02-09  285.040009  280.583344  283.153320  283.153320   45473100
# 2021-02-10  281.213318  266.673340  268.273346  268.273346  108648300
# 2021-02-11  270.813324  267.243347  270.553345  270.553345   64868400
# 2021-02-12  267.086670  261.776672  272.040009  272.040009   71304900
#
#             Open:30 days rolling
# Date
# 2021-02-01                   NaN
# 2021-02-02                   NaN
# 2021-02-03                   NaN
# 2021-02-04                   NaN
# ...

# %%
month_tesla[['Open','Open:30 days rolling']].plot(figsize=(12,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Assignment
# #### news
# 1. Read the Microsoft Data using Pandas Data reader
# 2. Get the maximum price of the share from 2017 to 2022
# 3. Which is the date of the highest price of the stock?
# 4. Which is the date of the lowest price of the stock?

# %%
# 1. Read the Microsoft Data using Pandas Data reader
msoft = yfinance.download(tickers='MSFT')
msoft
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1986-03-13    0.088542    0.101563    0.088542    0.097222    0.060657
# 1986-03-14    0.097222    0.102431    0.097222    0.100694    0.062823
# 1986-03-17    0.100694    0.103299    0.100694    0.102431    0.063907
# 1986-03-18    0.102431    0.103299    0.098958    0.099826    0.062281
# 1986-03-19    0.099826    0.100694    0.097222    0.098090    0.061198
# ...                ...         ...         ...         ...         ...
# 2023-04-10  289.209991  289.600006  284.709991  289.390015  289.390015
# 2023-04-11  285.750000  285.980011  281.640015  282.829987  282.829987
# 2023-04-12  284.790009  287.010010  281.959991  283.489990  283.489990
# 2023-04-13  283.589996  289.899994  283.170013  289.839996  289.839996
# 2023-04-14  287.000000  288.480011  283.690002  286.140015  286.140015
#
#                 Volume
# Date
# ...

# %%
# 2. Get the maximum price of the share from 2017 to 2022
two = msoft.loc['2017' : '2022']
two
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-01-03   62.790001   62.840000   62.130001   62.580002   57.501339
# 2017-01-04   62.480000   62.750000   62.119999   62.299999   57.244080
# 2017-01-05   62.189999   62.660000   62.029999   62.299999   57.244080
# 2017-01-06   62.299999   63.150002   62.040001   62.840000   57.740250
# 2017-01-09   62.759998   63.080002   62.540001   62.639999   57.556484
# ...                ...         ...         ...         ...         ...
# 2022-12-23  236.110001  238.869995  233.940002  238.729996  238.133545
# 2022-12-27  238.699997  238.929993  235.830002  236.960007  236.367981
# 2022-12-28  236.889999  239.720001  234.169998  234.529999  233.944031
# 2022-12-29  235.649994  241.919998  235.649994  241.009995  240.407837
# 2022-12-30  238.210007  239.960007  236.660004  239.820007  239.220825
#
#               Volume
# Date
# 2017-01-03  20694100
# 2017-01-04  21340000
# 2017-01-05  24876000
# ...

# %%
maximum = msoft['High'].max()
maximum
# Out:
# 349.6700134277344

# %%
# 3. Which is the date of the highest price of the stock?
msoft['High'][msoft['High'] == maximum]
# Out:
# Date
# 2021-11-22    349.670013
# Name: High, dtype: float64

# %%
minimum = msoft['High'].min()
minimum
# Out:
# 0.09201399981975555

# %%
# 4. Which is the date of the lowest price of the stock?
msoft['High'][msoft['High'] == minimum]
# Out:
# Date
# 1986-03-25    0.092014
# Name: High, dtype: float64

# %%
msoft['High'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>
